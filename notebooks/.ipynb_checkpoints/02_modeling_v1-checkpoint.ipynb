# %%
import numpy as np
import pandas as pd

# Models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Optional (we'll use later)
import xgboost as xgb

# %%
# Example (adjust to your file)
X_train = pd.read_csv("X_train.csv")
X_test = pd.read_csv("X_test.csv")
y_train = pd.read_csv("y_train.csv").squeeze()
y_test = pd.read_csv("y_test.csv").squeeze()
print("CES")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Example (adjust to your file)
# ----> 2 X_train = pd.read_csv("X_train.csv")
#       3 X_test = pd.read_csv("X_test.csv")
#       4 y_train = pd.read_csv("y_train.csv").squeeze()
#
# ...

# %%
print(type(y_test_sample))
print(type(y_pred_lr))
print(len(y_test_sample))
print(len(y_pred_lr))
# Out:
# <class 'pandas.core.series.Series'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 print(type(y_test_sample))
# ----> 2 print(type(y_pred_lr))
#       3 print(len(y_test_sample))
#       4 print(len(y_pred_lr))
#
# NameError: name 'y_pred_lr' is not defined

# %%
def evaluate_model(y_true, y_pred, model_name):
    """
    Evaluates model performance using RMSE and MAE.

    Parameters:
    y_true (array): Actual sales values
    y_pred (array): Predicted sales values
    model_name (str): Name of the model being evaluated

    Returns:
    None (prints results)
    """
    
    # Root Mean Squared Error (penalizes large errors)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    
    # Mean Absolute Error (average error)
    mae = mean_absolute_error(y_true, y_pred)
    
    print(f"{model_name} Performance:")
    print(f"RMSE: {rmse:.2f}")
    print(f"MAE: {mae:.2f}")
    print("-" * 30)
    print("CES")
